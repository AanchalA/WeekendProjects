# %% [markdown]
# <a href="https://colab.research.google.com/github/AanchalA/WeekendProjects/blob/main/Stable_Diffusion_VAE_From_Scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variational Autoencoders (VAEs) are a type of deep generative model widely used for tasks like image generation, compression, and representation learning. They combine probabilistic modeling and neural networks to learn compact latent representations of data. VAEs are particularly useful for generating high-quality, diverse outputs while ensuring smooth interpolation in the latent space.
#
# This project focuses on building a Stable Diffusion VAE from scratch. The goal is to encode input images into a lower-dimensional latent space and reconstruct them with high fidelity. Key aspects of the implementation include:
#
# - Encoder-Decoder Architecture: The encoder compresses the input into a latent representation, while the decoder reconstructs the input from this representation.
# - Attention Mechanisms: These improve the model's ability to focus on important regions of the input, capturing global dependencies.
# - Residual Connections: These ensure efficient gradient flow, allowing for deeper network architectures without the risk of vanishing gradients.
# - Reparameterization Trick: This ensures differentiability during backpropagation by sampling latent variables in a way that allows gradient computation.
#
# The implementation uses PyTorch to create the VAE, incorporating components like self-attention, group normalization, and skip connections. The model is trained on a dataset of dog images, demonstrating its capability to learn meaningful latent representations and generate high-quality reconstructions.

# %%
import os
import math
import shutil
import torch
import torchvision
from torch import nn
from tqdm.auto import tqdm
import torch.optim as optim
from torchvision import transforms
from torch.nn import functional as F
from sklearn.model_selection import train_test_split

# %%
try:
    from torchinfo import summary
except:
    print("[INFO] Couldn't find torchinfo... installing it.")
    # !pip install -q torchinfo
    from torchinfo import summary
# Out:
# [INFO] Couldn't find torchinfo... installing it.

# %% [markdown]
# # Self Attention

# %%
class SelfAttention(nn.Module):
    def __init__(self, n_heads, embedding_dimensions, in_projection_bias=True, out_projection_bias=True):
        """
        Multi-head Self-Attention module.
        Args:
            n_heads (int): Number of attention heads.
            embedding_dimensions (int): Dimensionality of input embeddings.
            in_projection_bias (bool, optional): If True, includes a bias term in input projections. Defaults to True.
            out_projection_bias (bool, optional): If True, includes a bias term in output projection. Defaults to True.
        """
        super().__init__()
        assert embedding_dimensions % n_heads == 0, "Embedding dimensions must be divisible by number of heads."

        self.n_heads = n_heads
        self.embedding_dimensions = embedding_dimensions
        self.d_heads = embedding_dimensions // n_heads

        # Combined projection for Q, K, V
        self.in_projection = nn.Linear(in_features=embedding_dimensions,
                                       out_features=3 * embedding_dimensions,
                                       bias=in_projection_bias)

        self.out_projection = nn.Linear(in_features=embedding_dimensions,
                                        out_features=embedding_dimensions,
                                        bias=out_projection_bias)


    def forward(self, x, causal_mask=False):
        """
        Forward pass for self-attention.
        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, seq_len, embedding_dimensions).
            causal_mask (bool, optional): If True, applies a causal mask to prevent attention to future tokens. Defaults to False.
        Returns:
            torch.Tensor: Output tensor after self-attention of shape (batch_size, seq_len, embedding_dimensions).
        """

        batch_size, seq_len, embed_dim = x.shape     ## seq_len = image_height * image_width
        assert embed_dim == self.embedding_dimensions, "Input embedding dimension mismatch."

        # Project input to Q, K, V
        qkv = self.in_projection(x)  # Shape: (batch_size, seq_len, 3 * embedding_dimensions)
        # Splitting in_projections into Q, K, V
        q, k, v = qkv.chunk(3, dim=-1)  # Each: (batch_size, seq_len, embedding_dimensions)

        # Reshape and transpose Q, K, V for multi-head attention to allow parallel computation across heads.
        # (batch_size, seq_len, embedding_dimensions) -->
        # --> (batch_size, seq_len, n_heads, d_heads) -->
        # --> (batch_size, n_heads, seq_len, d_head)
        interim_shape = (batch_size, seq_len, self.n_heads, self.d_heads)
        q = q.view(interim_shape).transpose(1, 2)
        k = k.view(interim_shape).transpose(1, 2)
        v = v.view(interim_shape).transpose(1, 2)

        ## Compute scaled dot-product atttention scores
        # (batch_size, n_heads, seq_len, d_head) * (batch_size, n_heads, d_head, seq_len)
        # = (batch_size, n_heads, seq_len, seq_len)
        atttention_scores = torch.matmul(q, k.transpose(-1, -2))
        atttention_scores /= math.sqrt(self.d_heads)

        if causal_mask:
            # Create a causal mask to prevent attention to future tokens
            # mask where the upper triangle above the principle diagonal in 1
            mask = torch.triu(torch.ones_like(atttention_scores, device=x.device), diagonal=1).bool()
            # Fill the upper triangle with -inf
            atttention_scores = atttention_scores.masked_fill(mask.unsqueeze(0).unsqueeze(0), float('-inf'))

        # Apply softmax to get attention weights
        atttention_weights = torch.softmax(atttention_scores, dim=-1)  # (batch_size, n_heads, seq_len, seq_len)

        # Contextulazied embeddings: Apply attention weights to values
        output = atttention_scores @ v      # (batch_size, n_heads, seq_len, d_head)

        # Concatenate heads and project the output
        output = output.transpose(1, 2).contiguous()     # (batch_size, seq_len, n_heads, d_head)
        # Change the shape to the shape of out_projection
        output = output.view(batch_size, seq_len, self.embedding_dimensions)  # (batch_size, seq_len, embedding_dimensions)

        # Final linear projection
        output = self.out_projection(output)        # (batch_size, seq_len, embedding_dimensions)

        return output

# %% [markdown]
# # Attention Block
#
# This attention block uses self attention using residual technique with group norms as all the features we have are pixels, and attention tries to find what are good features to pay attention in all features.

# %%
class AttentionBlock(nn.Module):
    def __init__(self, num_channels, num_groups=32, n_heads=1, dropout_rate=0.1,
                 in_projection_bias=True, out_projection_bias=True):
        """
        Attention block with Group Normalization and Self-Attention.
        Args:
            channels (int): Number of input channels.
            num_groups (int, optional): Number of groups for GroupNorm. Must divide channels evenly. Defaults to 32.
            n_heads (int, optional): Number of attention heads. Defaults to 1.
            in_projection_bias (bool, optional): If True, adds a bias term to the input projection layer. Defaults to True.
            out_projection_bias (bool, optional): If True, adds a bias term to the output projection layer. Defaults to True.
            dropout_rate (float, optional): Dropout probability. Defaults to 0.1.
        """
        super().__init__()

         # Ensure that the number of groups divides the number of channels
        assert num_channels % num_groups == 0, (
            f"Number of channels ({num_channels}) must be divisible by "
            f"num_groups ({num_groups}).")

        # Group Normalization for Attention Layer
        self.group_norm_1 = nn.GroupNorm(num_groups=num_groups, num_channels=num_channels)

        # Self-Attention
        self.attention = SelfAttention(n_heads=n_heads, embedding_dimensions=num_channels,
                                       in_projection_bias=in_projection_bias,
                                       out_projection_bias=out_projection_bias)

        # Add dropout after attention
        self.dropout_1 = nn.Dropout(p=dropout_rate)

        # # Second Group Normalization for Feed-Forward Network
        # self.group_norm_2 = nn.GroupNorm(num_groups=num_groups, num_channels=num_channels)

        # # Feed-Forward Network
        # self.feed_forward = nn.Sequential(nn.Linear(in_features=num_channels, out_features=num_channels*4),
        #                                   nn.ReLU(inplace=True),
        #                                   nn.Linear(in_features=num_channels*4, out_features=num_channels))

        # # Add dropout after the Feed-Forward Network
        # self.dropout_2 = nn.Dropout(p=dropout_rate)


    def forward(self, x):
        """
        Forward pass for the AttentionBlock.
        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, channels, height, width).
        Returns:
            torch.Tensor: Output tensor of shape (batch_size, channels, height, width).
        """

        # For residual connection after attention
        residual = x.clone()

        # Apply Group Normalization
        x = self.group_norm_1(x)     # (B, C, H, W)

        # x: batch_size(B), num_channels(C), image_height(H), image_width(W)
        batch_size, num_channels, image_height, image_width = x.shape

        x = x.view((batch_size, num_channels, image_height * image_width))        # (B, C, H*W)
        x = x.permute(0, 2, 1)         # (B, H*W, C)

        # Apply Self-Attention without Mask
        x = self.attention(x)   # (B, H*W, C)

        # Apply Dropout after Self-Attention
        x = self.dropout_1(x)  # (B, H*W, C)

        # Reshape back to spatial dimensions
        x = x.permute(0, 2, 1).contiguous()    # (B, C, H*W)
        x = x.view((batch_size, num_channels, image_height, image_width))       # (B, C, H, W)

        # Add residual connection
        x += residual   # (B, C, H, W)

        # # Residual for feed-forward
        # residual = x

        # # Apply Group Normalization for feed-forward network
        # x = self.group_norm_2(x)  # (B, C, H, W)
        # x = x.view(batch_size, num_channels, image_height * image_width)  # (B, C, H*W)
        # x = x.permute(0, 2, 1)  # (B, H*W, C)

        # # Apply Feed-Forward Network
        # x = self.feed_forward(x)  # (B, H*W, C)

        # # Apply Dropout after the Feed-Forward Network
        # x = self.dropout_2(x)

        # # Reshape back to spatial dimensions
        # x = x.permute(0, 2, 1).contiguous()  # (B, C, H*W)
        # x = x.view(batch_size, num_channels, image_height, image_width)  # (B, C, H, W)

        # # Add residual connection
        # x += residual  # (B, C, H, W)

        return x

# %% [markdown]
# # ResidualBlock
#
# This ResidualBlock will be used in Encoder and Decoder

# %%
class SEBlock(nn.Module):
    """
    Enhancing the residual block with SE modules can improve the network's ability to model channel-wise dependencies.
    """
    def __init__(self, channels, reduction=16):
        super(SEBlock, self).__init__()
        self.se = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(channels, channels // reduction, kernel_size=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(channels // reduction, channels, kernel_size=1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return x * self.se(x)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, in_channels, out_channels, num_groups=32,
                 kernel_size=3, padding=1, stride=1):
        """
        Residual Block with Group Normalization and Convolutional Layers.
        Args:
            in_channels (int): Number of input channels.
            out_channels (int): Number of output channels.
            num_groups (int, optional): Number of groups for GroupNorm. Must divide in_channels and out_channels evenly. Defaults to 32.
            kernel_size (int, optional): Kernel size for convolutional layers. Defaults to 3.
            padding (int, optional): Padding for convolutional layers. Defaults to 1.
            stride (int, optional): Stride for convolutional layers. Defaults to 1.
        """
        super().__init__()

        # Ensure that the number of groups divides the number of channels
        assert in_channels % num_groups == 0, (
            f"Number of channels ({in_channels}) must be divisible by "
            f"num_groups ({num_groups}).")

        assert out_channels % num_groups == 0, (
            f"Number of channels ({out_channels}) must be divisible by "
            f"num_groups ({num_groups}).")

        self.group_norm_1 = nn.GroupNorm(num_groups=num_groups, num_channels=in_channels)
        self.conv_1 = nn.Conv2d(in_channels=in_channels, out_channels=out_channels, kernel_size=3, padding=1)

        self.group_norm_2 = nn.GroupNorm(num_groups=num_groups, num_channels=out_channels)
        self.conv_2 = nn.Conv2d(in_channels=out_channels, out_channels=out_channels, kernel_size=3, padding=1)

        if in_channels == out_channels:
            # the input is added directly to the output.
            self.residual_layer = nn.Identity()
        else:
            # a 1x1 convolutional layer to the input's channel dimensions to match the output for proper addition.
            self.residual_layer = nn.Conv2d(in_channels, out_channels, kernel_size=1, padding=0)

        # Initialize weights
        # self._initialize_weights()

        # Integrate SEBlock into ResidualBlock
        # self.se = SEBlock(out_channels)


    def forward(self, x):
        """
        Forward pass for the ResidualBlock.
        Args:
            x (torch.Tensor): Input tensor of shape (batch_size, in_channels, height, width).
        Returns:
            torch.Tensor: Output tensor of shape (batch_size, out_channels, height_out, width_out).
        """

        # x: (B, IN_C, H, W)

        residue = x.clone()

        x = self.group_norm_1(x)
        x = torch.selu(x)
        x = self.conv_1(x)

        x = self.group_norm_2(x)
        x = self.conv_2(x)

        # x = self.se(x)
        x += self.residual_layer(residue)

        return x

    def _initialize_weights(self):
        """
        Initializes weights of convolutional layers using Kaiming Normal initialization.
        """
        for m in self.modules():

            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

            elif isinstance(m, nn.GroupNorm):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

# %% [markdown]
# # Encoder Block
#
#
# This Encoder Block is designed to transform input images into lower-dimensional latent representations.
#
# Key Components:
# - **Convolutional Layers:** Extract hierarchical features from the input images, capturing spatial hierarchies and patterns.
# - **Residual Blocks:** Facilitate the construction of deeper networks by allowing gradients to flow more effectively, mitigating issues like vanishing gradients.
#
# Forward Pass:
# - **Feature Extraction:** The input image is passed through a series of convolutional layers and residual blocks to extract meaningful features.
# - **Latent Representation:** From the extracted features, the forward method computes the mean and standard deviation.
# - **Latent Vector:** These statistics are combined to generate the final latent vector, which serves as a compact representation of the input image in the latent space.

# %%
class Encoder(nn.Sequential):
    def __init__(self):
        """
        Encoder Block to transform input images into lower-dimensional latent representations.

        Architecture:
        - Multiple convolutional layers with residual connections for deep feature extraction.
        - Attention mechanism to capture global dependencies.
        - Group Normalization and activation functions to stabilize and introduce non-linearity.
        - Outputs latent variables using the reparameterization trick for probabilistic modeling.
        """
        super().__init__(

            # Initial Convolution:
            # (B, C=3(Colour Channels), H, W) --> (B, C=128(num kernels), H, W)
            nn.Conv2d(3, 128, kernel_size=3, padding=1),
            # --> (B, 128, H, W)
            ResidualBlock(128, 128),

            # Downsampling:
            # --> (B, 128, H / 2, W / 2)
            nn.Conv2d(128, 128, kernel_size=3, stride=2, padding=0),
            # --> (B, 256, H / 2, W / 2)
            ResidualBlock(128, 256),
            # --> (B, 256, H / 2, W / 2)
            ResidualBlock(256, 256),

            # Downsampling:
            # --> (B, 256, H / 4, W / 4)
            nn.Conv2d(256, 256, kernel_size=3, stride=2, padding=0),
             # --> (B, 512, H / 4, W / 4)
            ResidualBlock(256, 512),
            # --> (B, 512, H / 4, W / 4)
            ResidualBlock(512, 512),

            # Downsampling:
            # --> (B, 512, H / 8, W / 8)
            nn.Conv2d(512, 512, kernel_size=3, stride=2, padding=0),
            # --> (B, 512, H / 8, W / 8)
            ResidualBlock(512, 512),
            # --> (B, 512, H / 8, W / 8)
            ResidualBlock(512, 512),
            # --> (B, 512, H / 8, W / 8)
            ResidualBlock(512, 512),

            # Attention Mechanism:
            # --> (B, 512, H / 8, W / 8)
            AttentionBlock(512),

            # Residual Connection Post-Attention:
            # --> (B, 512, H / 8, W / 8)
            ResidualBlock(512, 512),

            # Group Normalization and Activation:
            # --> (B, 512, H / 8, W / 8)
            nn.GroupNorm(32, 512),
            # --> (B, 512, H / 8, W / 8)
            nn.SiLU(),

            # Final Convolutions:
            # --> (B, 8, H / 8, W / 8)
            nn.Conv2d(512, 8, kernel_size=3, padding=1),
            # --> (B, 8, H / 8, W / 8)
            nn.Conv2d(8, 8, kernel_size=1, padding=0),
        )


    def forward(self, x):
        """
        Forward pass for the Encoder.
        Args:
            x (torch.Tensor): Input tensor of shape (Batch Size, 3, Height, Width).
        Returns:
            torch.Tensor: Latent tensor 'z' of shape (Batch Size, 4, H/8, W/8).
        """
        # x: (B, C, H, W)

        # Iterate through each module in the sequential layers
        for module in self:
            if isinstance(module, nn.Conv2d) and module.stride == (2, 2):
                # Apply padding before downsampling convolutions to maintain spatial consistency
                # to ensure that the spatial dimensions are divisible by the stride, preventing issues like size mismatch during downsampling.
                x = F.pad(x, (0, 1, 0, 1))      ## (left, right, top, bottom)
            x = module(x)

        # Split x into mean and log_variance for latent variables
        # X: (B, 8, H / 8, W / 8) --> Two tensors of shape (B, 4, H / 8, W / 8)
        mean, log_variance = torch.chunk(x, 2, dim=1)

        # Clamp log variance between -30 and 20
        # Prevents extreme values in log_variance that could lead to numerical instability during training.
        log_variance = torch.clamp(log_variance, -30, 20)

        # Reparameterization Trick: z = mean + std * epsilon
        # Compute standard deviation from log_variance
        std = torch.exp(0.5 * log_variance)
        # Sample epsilon from standard normal distribution
        eps = torch.randn_like(std)

        # Compute the latent variable
        # Allows for backpropagation through stochastic sampling by expressing the latent variable x as a deterministic function of mean, std, and a random variable eps.
        x = mean + eps * std

        # Scale the latent representation
        x *= 0.18215

        return x       # (B, 4, H/8, W/8)

# %% [markdown]
# # Decoder Block
#
#
# This Decoder Block transforms latent representations back into their original image dimensions.
#
# Key Components:
# - **Attention Block:** Enhances the decoder's ability to focus on relevant features by capturing long-range dependencies within the latent space.
# - **Residual Blocks:** Facilitate the construction of deeper networks by allowing gradients to flow more effectively, mitigating issues like vanishing gradients.
# - **Upsample Layer:** Increases the spatial dimensions of the feature maps, progressively restoring the image to its original size.
#
# Forward Pass:
# 1. **Attention Mechanism:** Applies the attention block to the latent representations, enabling the decoder to attend to significant features.
# 2. **Residual Processing:** Passes the data through a series of residual blocks to refine and reconstruct detailed features.
# 3. **Upsampling:** Utilizes upsample layers (e.g., nearest-neighbor or transposed convolutions) to expand the feature maps' spatial dimensions, gradually rebuilding the original image size.
# 4. **Final Output:** Produces the reconstructed image with the same dimensions as the input, completing the decoding process.

# %%
class Decoder(nn.Sequential):
    def __init__(self):
        super().__init__(
            # (B, 4, 32, 32) --> (B, 512, 32, 32)
            nn.Conv2d(4, 512, kernel_size=3, padding=1),

            # --> (B, 512, 32, 32)
            ResidualBlock(512, 512),

            # --> (B, 512, 32, 32)
            AttentionBlock(512),

            # --> (B, 512, 32, 32)
            ResidualBlock(512, 512),

            # --> (B, 512, 32, 32)
            ResidualBlock(512, 512),

            # --> (B, 512, 32, 32)
            ResidualBlock(512, 512),

            # --> (B, 512, 64, 64)
            nn.Upsample(scale_factor=2),

            # --> (B, 512, 64, 64)
            nn.Conv2d(512, 512, kernel_size=3, padding=1),

            # --> (B, 512, 64, 64)
            ResidualBlock(512, 512),

            # --> (B, 512, 64, 64)
            ResidualBlock(512, 512),

            # --> (B, 512, 64, 64)
            ResidualBlock(512, 512),

            # --> (B, 512, 128, 128)
            nn.Upsample(scale_factor=2),

             # --> (B, 512, 128, 128)
            nn.Conv2d(512, 512, kernel_size=3, padding=1),

            # --> (B, 256, 128, 128)
            ResidualBlock(512, 256),

            # --> (B, 256, 128, 128)
            ResidualBlock(256, 256),

            # --> (B, 256, 128, 128)
            ResidualBlock(256, 256),

            # --> (B, 256, 256, 256)
            nn.Upsample(scale_factor=2),

             # --> (B, 256, 256, 256)
            nn.Conv2d(256, 256, kernel_size=3, padding=1),

            # --> (B, 128, 256, 256)
            ResidualBlock(256, 128),

            # --> (B, 128, 256, 256)
            ResidualBlock(128, 128),

            # --> (B, 128, 256, 256)
            ResidualBlock(128, 128),

            # --> (B, 128, 256, 256)
            nn.GroupNorm(32, 128),

            # --> (B, 128, 256, 256)
            nn.SiLU(),

            # # --> (B, 3, 256, 256)
            nn.Conv2d(128, 3, kernel_size=3, padding=1)
        )


    def forward(self, x):
        # x: (B, 4, H/8, W/8)

        # Remove the scaling added by the encoder
        x /= 0.18215

        for module in self:
            x = module(x)

        # (B, 3, H=256, W=256)
        return x

# %% [markdown]
# # Variational Auto Encoder Module

# %%
class VariationalAutoEncoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = Encoder()
        self.decoder = Decoder()

    def forward(self, x):
        # print(f"Input Shape: {x.shape}")
        encoded = self.encoder(x)
        # print(f"Images Encoded: {encoded.shape}")
        decoded = self.decoder(encoded)
        # print(f"X Decoded: {decoded.shape}")
        return encoded, decoded

# %%
summary(model=VariationalAutoEncoder(),
        input_size=(4, 3, 56, 56),               ### [batch_size, num_channels, Height, Width]
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
        )
# Out:
# ==================================================================================================================================
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ==================================================================================================================================
# VariationalAutoEncoder (VariationalAutoEncoder)    [4, 3, 56, 56]       [4, 4, 7, 7]         --                   True
# ├─Encoder (encoder)                                [4, 3, 56, 56]       [4, 4, 7, 7]         --                   True
# │    └─Conv2d (0)                                  [4, 3, 56, 56]       [4, 128, 56, 56]     3,584                True
# │    └─ResidualBlock (1)                           [4, 128, 56, 56]     [4, 128, 56, 56]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 128, 56, 56]     [4, 128, 56, 56]     256                  True
# │    │    └─Conv2d (conv_1)                        [4, 128, 56, 56]     [4, 128, 56, 56]     147,584              True
# │    │    └─GroupNorm (group_norm_2)               [4, 128, 56, 56]     [4, 128, 56, 56]     256                  True
# │    │    └─Conv2d (conv_2)                        [4, 128, 56, 56]     [4, 128, 56, 56]     147,584              True
# │    │    └─Identity (residual_layer)              [4, 128, 56, 56]     [4, 128, 56, 56]     --                   --
# │    └─Conv2d (2)                                  [4, 128, 57, 57]     [4, 128, 28, 28]     147,584              True
# │    └─ResidualBlock (3)                           [4, 128, 28, 28]     [4, 256, 28, 28]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 128, 28, 28]     [4, 128, 28, 28]     256                  True
# │    │    └─Conv2d (conv_1)                        [4, 128, 28, 28]     [4, 256, 28, 28]     295,168              True
# │    │    └─GroupNorm (group_norm_2)               [4, 256, 28, 28]     [4, 256, 28, 28]     512                  True
# │    │    └─Conv2d (conv_2)                        [4, 256, 28, 28]     [4, 256, 28, 28]     590,080              True
# │    │    └─Conv2d (residual_layer)                [4, 128, 28, 28]     [4, 256, 28, 28]     33,024               True
# │    └─ResidualBlock (4)                           [4, 256, 28, 28]     [4, 256, 28, 28]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 256, 28, 28]     [4, 256, 28, 28]     512                  True
# │    │    └─Conv2d (conv_1)                        [4, 256, 28, 28]     [4, 256, 28, 28]     590,080              True
# │    │    └─GroupNorm (group_norm_2)               [4, 256, 28, 28]     [4, 256, 28, 28]     512                  True
# │    │    └─Conv2d (conv_2)                        [4, 256, 28, 28]     [4, 256, 28, 28]     590,080              True
# │    │    └─Identity (residual_layer)              [4, 256, 28, 28]     [4, 256, 28, 28]     --                   --
# │    └─Conv2d (5)                                  [4, 256, 29, 29]     [4, 256, 14, 14]     590,080              True
# │    └─ResidualBlock (6)                           [4, 256, 14, 14]     [4, 512, 14, 14]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 256, 14, 14]     [4, 256, 14, 14]     512                  True
# │    │    └─Conv2d (conv_1)                        [4, 256, 14, 14]     [4, 512, 14, 14]     1,180,160            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 14, 14]     [4, 512, 14, 14]     1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    │    └─Conv2d (residual_layer)                [4, 256, 14, 14]     [4, 512, 14, 14]     131,584              True
# │    └─ResidualBlock (7)                           [4, 512, 14, 14]     [4, 512, 14, 14]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 14, 14]     [4, 512, 14, 14]     1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 14, 14]     [4, 512, 14, 14]     1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 14, 14]     [4, 512, 14, 14]     --                   --
# │    └─Conv2d (8)                                  [4, 512, 15, 15]     [4, 512, 7, 7]       2,359,808            True
# │    └─ResidualBlock (9)                           [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 7, 7]       [4, 512, 7, 7]       --                   --
# │    └─ResidualBlock (10)                          [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 7, 7]       [4, 512, 7, 7]       --                   --
# │    └─ResidualBlock (11)                          [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 7, 7]       [4, 512, 7, 7]       --                   --
# │    └─AttentionBlock (12)                         [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─SelfAttention (attention)              [4, 49, 512]         [4, 49, 512]         1,050,624            True
# │    │    └─Dropout (dropout_1)                    [4, 49, 512]         [4, 49, 512]         --                   --
# │    └─ResidualBlock (13)                          [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 7, 7]       [4, 512, 7, 7]       --                   --
# │    └─GroupNorm (14)                              [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    └─SiLU (15)                                   [4, 512, 7, 7]       [4, 512, 7, 7]       --                   --
# │    └─Conv2d (16)                                 [4, 512, 7, 7]       [4, 8, 7, 7]         36,872               True
# │    └─Conv2d (17)                                 [4, 8, 7, 7]         [4, 8, 7, 7]         72                   True
# ├─Decoder (decoder)                                [4, 4, 7, 7]         [4, 3, 56, 56]       --                   True
# │    └─Conv2d (0)                                  [4, 4, 7, 7]         [4, 512, 7, 7]       18,944               True
# │    └─ResidualBlock (1)                           [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 7, 7]       [4, 512, 7, 7]       --                   --
# │    └─AttentionBlock (2)                          [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─SelfAttention (attention)              [4, 49, 512]         [4, 49, 512]         1,050,624            True
# │    │    └─Dropout (dropout_1)                    [4, 49, 512]         [4, 49, 512]         --                   --
# │    └─ResidualBlock (3)                           [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 7, 7]       [4, 512, 7, 7]       --                   --
# │    └─ResidualBlock (4)                           [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 7, 7]       [4, 512, 7, 7]       --                   --
# │    └─ResidualBlock (5)                           [4, 512, 7, 7]       [4, 512, 7, 7]       --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 7, 7]       [4, 512, 7, 7]       1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 7, 7]       [4, 512, 7, 7]       2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 7, 7]       [4, 512, 7, 7]       --                   --
# │    └─Upsample (6)                                [4, 512, 7, 7]       [4, 512, 14, 14]     --                   --
# │    └─Conv2d (7)                                  [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    └─ResidualBlock (8)                           [4, 512, 14, 14]     [4, 512, 14, 14]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 14, 14]     [4, 512, 14, 14]     1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 14, 14]     [4, 512, 14, 14]     1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 14, 14]     [4, 512, 14, 14]     --                   --
# │    └─ResidualBlock (9)                           [4, 512, 14, 14]     [4, 512, 14, 14]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 14, 14]     [4, 512, 14, 14]     1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 14, 14]     [4, 512, 14, 14]     1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 14, 14]     [4, 512, 14, 14]     --                   --
# │    └─ResidualBlock (10)                          [4, 512, 14, 14]     [4, 512, 14, 14]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 14, 14]     [4, 512, 14, 14]     1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    │    └─GroupNorm (group_norm_2)               [4, 512, 14, 14]     [4, 512, 14, 14]     1,024                True
# │    │    └─Conv2d (conv_2)                        [4, 512, 14, 14]     [4, 512, 14, 14]     2,359,808            True
# │    │    └─Identity (residual_layer)              [4, 512, 14, 14]     [4, 512, 14, 14]     --                   --
# │    └─Upsample (11)                               [4, 512, 14, 14]     [4, 512, 28, 28]     --                   --
# │    └─Conv2d (12)                                 [4, 512, 28, 28]     [4, 512, 28, 28]     2,359,808            True
# │    └─ResidualBlock (13)                          [4, 512, 28, 28]     [4, 256, 28, 28]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 512, 28, 28]     [4, 512, 28, 28]     1,024                True
# │    │    └─Conv2d (conv_1)                        [4, 512, 28, 28]     [4, 256, 28, 28]     1,179,904            True
# │    │    └─GroupNorm (group_norm_2)               [4, 256, 28, 28]     [4, 256, 28, 28]     512                  True
# │    │    └─Conv2d (conv_2)                        [4, 256, 28, 28]     [4, 256, 28, 28]     590,080              True
# │    │    └─Conv2d (residual_layer)                [4, 512, 28, 28]     [4, 256, 28, 28]     131,328              True
# │    └─ResidualBlock (14)                          [4, 256, 28, 28]     [4, 256, 28, 28]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 256, 28, 28]     [4, 256, 28, 28]     512                  True
# │    │    └─Conv2d (conv_1)                        [4, 256, 28, 28]     [4, 256, 28, 28]     590,080              True
# │    │    └─GroupNorm (group_norm_2)               [4, 256, 28, 28]     [4, 256, 28, 28]     512                  True
# │    │    └─Conv2d (conv_2)                        [4, 256, 28, 28]     [4, 256, 28, 28]     590,080              True
# │    │    └─Identity (residual_layer)              [4, 256, 28, 28]     [4, 256, 28, 28]     --                   --
# │    └─ResidualBlock (15)                          [4, 256, 28, 28]     [4, 256, 28, 28]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 256, 28, 28]     [4, 256, 28, 28]     512                  True
# │    │    └─Conv2d (conv_1)                        [4, 256, 28, 28]     [4, 256, 28, 28]     590,080              True
# │    │    └─GroupNorm (group_norm_2)               [4, 256, 28, 28]     [4, 256, 28, 28]     512                  True
# │    │    └─Conv2d (conv_2)                        [4, 256, 28, 28]     [4, 256, 28, 28]     590,080              True
# │    │    └─Identity (residual_layer)              [4, 256, 28, 28]     [4, 256, 28, 28]     --                   --
# │    └─Upsample (16)                               [4, 256, 28, 28]     [4, 256, 56, 56]     --                   --
# │    └─Conv2d (17)                                 [4, 256, 56, 56]     [4, 256, 56, 56]     590,080              True
# │    └─ResidualBlock (18)                          [4, 256, 56, 56]     [4, 128, 56, 56]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 256, 56, 56]     [4, 256, 56, 56]     512                  True
# │    │    └─Conv2d (conv_1)                        [4, 256, 56, 56]     [4, 128, 56, 56]     295,040              True
# │    │    └─GroupNorm (group_norm_2)               [4, 128, 56, 56]     [4, 128, 56, 56]     256                  True
# │    │    └─Conv2d (conv_2)                        [4, 128, 56, 56]     [4, 128, 56, 56]     147,584              True
# │    │    └─Conv2d (residual_layer)                [4, 256, 56, 56]     [4, 128, 56, 56]     32,896               True
# │    └─ResidualBlock (19)                          [4, 128, 56, 56]     [4, 128, 56, 56]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 128, 56, 56]     [4, 128, 56, 56]     256                  True
# │    │    └─Conv2d (conv_1)                        [4, 128, 56, 56]     [4, 128, 56, 56]     147,584              True
# │    │    └─GroupNorm (group_norm_2)               [4, 128, 56, 56]     [4, 128, 56, 56]     256                  True
# │    │    └─Conv2d (conv_2)                        [4, 128, 56, 56]     [4, 128, 56, 56]     147,584              True
# │    │    └─Identity (residual_layer)              [4, 128, 56, 56]     [4, 128, 56, 56]     --                   --
# │    └─ResidualBlock (20)                          [4, 128, 56, 56]     [4, 128, 56, 56]     --                   True
# │    │    └─GroupNorm (group_norm_1)               [4, 128, 56, 56]     [4, 128, 56, 56]     256                  True
# │    │    └─Conv2d (conv_1)                        [4, 128, 56, 56]     [4, 128, 56, 56]     147,584              True
# │    │    └─GroupNorm (group_norm_2)               [4, 128, 56, 56]     [4, 128, 56, 56]     256                  True
# │    │    └─Conv2d (conv_2)                        [4, 128, 56, 56]     [4, 128, 56, 56]     147,584              True
# │    │    └─Identity (residual_layer)              [4, 128, 56, 56]     [4, 128, 56, 56]     --                   --
# │    └─GroupNorm (21)                              [4, 128, 56, 56]     [4, 128, 56, 56]     256                  True
# │    └─SiLU (22)                                   [4, 128, 56, 56]     [4, 128, 56, 56]     --                   --
# │    └─Conv2d (23)                                 [4, 128, 56, 56]     [4, 3, 56, 56]       3,459                True
# ==================================================================================================================================
# Total params: 78,636,499
# Trainable params: 78,636,499
# Non-trainable params: 0
# Total mult-adds (G): 80.25
# ==================================================================================================================================
# Input size (MB): 0.15
# Forward/backward pass size (MB): 550.26
# Params size (MB): 314.55
# Estimated Total Size (MB): 864.95
# ==================================================================================================================================

# %% [markdown]
# # Configurations

# %%
# Device Configuration
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Hyperparameters

batch_size = 4
num_epochs = 100
learning_rate = 1e-4
beta = 0.00025          ## KL Divergence Weight

accumulation_steps = 1  # Adjust as needed
effective_batch_size = batch_size * accumulation_steps

# %% [markdown]
# # Download and Process The Training Dataset

# %%
def split_dataset(source_dir, train_dir, test_dir, test_size=0.2, random_state=42):
    image_files = [f for f in os.listdir(source_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    train_files, test_files = train_test_split(image_files, test_size=test_size, random_state=random_state)

    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)

    for file in train_files:
        shutil.copy(os.path.join(source_dir, file), os.path.join(train_dir, file))

    for file in test_files:
        shutil.copy(os.path.join(source_dir, file), os.path.join(test_dir, file))

    print(f"Dataset split complete. {len(train_files)} training images, {len(test_files)} test images.")

# %%
source_dir = "./all-dogs"
train_dir = "./data/train/dogs"
test_dir = "./data/test/dogs"

# %%
if os.path.isdir(train_dir):
    print(f"[INFO] {train_dir} directory exists, skipping download.")
else:
    print(f"[INFO] Did not find {train_dir} directory, creating one...")
    ! gdown 1KXRTB_q4uub_XOHecpsQjE4Kmv76sZbV
    ! unzip all-dogs.zip
    split_dataset(source_dir, train_dir, test_dir)
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating
#   inflating: all-dogs/n02109961_2932.jpg
#   inflating: all-dogs/n02088094_1618.jpg
#   inflating: all-dogs/n02098105_2103.jpg
#   inflating: all-dogs/n02093754_5266.jpg
#   inflating: all-dogs/n02105505_2942.jpg
#   inflating: all-dogs/n02108089_69.jpg
#   inflating: all-dogs/n02107908_298.jpg
#   inflating: all-dogs/n02105505_1293.jpg
#   inflating: all-dogs/n02108089_2831.jpg
#   inflating: all-dogs/n02088238_9025.jpg
#   inflating: all-dogs/n02096051_8892.jpg
#   inflating: all-dogs/n02107908_9.jpg
#   inflating: all-dogs/n02099849_410.jpg
#   inflating: all-dogs/n02113186_6418.jpg
#   inflating: all-dogs/n02089973_1458.jpg
#   inflating: all-dogs/n02107574_640.jpg
#   inflating: all-dogs/n02096437_3112.jpg
#   inflating: all-dogs/n02113712_142.jpg
#   inflating: all-dogs/n02093991_4490.jpg
#   inflating: all-dogs/n02086910_6882.jpg
#   inflating: all-dogs/n02093256_6473.jpg
#   inflating: all-dogs/n02112137_6314.jpg
# Dataset split complete. 16463 training images, 4116 test images.

# %% [markdown]
# # Data Loading and Transformation

# %%
transform = transforms.Compose([transforms.Resize(size=(56, 56)),
                                transforms.ToTensor(),
                                transforms.Normalize(mean=[0.5, 0.5, 0.5],
                                                     std=[0.5, 0.5, 0.5])])

# %%
dataset = torchvision.datasets.ImageFolder(root='./data/train', transform=transform)
dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True, pin_memory=True)

# %%
len(dataset), len(dataloader), len(dataset) / batch_size
# Out:
# (16463, 4116, 4115.75)

# %%
image, label = dataset[0]
print(image.shape, label)
# Out:
# torch.Size([3, 56, 56]) 0

# %% [markdown]
# # Model Training

# %%
model = VariationalAutoEncoder().to(device)

loss_fn = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

train_losses = list()

for epoch in tqdm(range(num_epochs)):
    model.train()
    train_loss = 0

    for index, (images, _) in enumerate(dataloader):
        images = images.to(device)

        # Forward Pass
        encoded, reconstructed = model(images)

        # Calculate the Loss
        reconstruction_loss = loss_fn(reconstructed, images)

        # Extract the mean and log_variance form the encoded images
        mean, log_variance = torch.chunk(encoded, 2, dim=1)         ## (b, `C`, h, w)

        kl_divergence = -0.5 * torch.sum(1 + log_variance - mean.pow(2) - log_variance.exp())
        loss = reconstruction_loss + beta * kl_divergence

        # Normalize the loss to account for accumulation
        loss /= accumulation_steps

        # Loss Backward
        loss.backward()

        if (index + 1) % accumulation_steps == 0:
            optimizer.zero_grad()
            optimizer.step()

        train_loss += loss.item() * accumulation_steps

        print(f'Epoch: [{epoch + 1} / {num_epochs}], Step: [{index + 1} / {len(dataloader)}] | '
              f'Loss: {loss.item() * accumulation_steps: .4f}, '
              f'Reconstruction Loss: {reconstruction_loss.item(): .4f}, '
              f'KL Div: {kl_divergence.item(): .4f}')


        model.eval()
        with torch.inference_mode():
            # Take the first image from the batch
            sample_image = images[0].unsqueeze(0)
            reconstructed_sample = model(sample_image)[1]

            sample_image = (sample_image * 0.5) + 0.5
            reconstructed_sample = (reconstructed_sample * 0.5) + 0.5

            torchvision.utils.save_image(reconstructed_sample, 'reconstructed.png')

    train_losses.append(train_loss / len(dataloader))

    # Save the model checkpoint
    torch.save(model.state_dict(), f'vae_model_epoch_{epoch + 1}.pth')

print('Training Completed!')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Epoch: [24 / 100], Step: [579 / 4116],Loss:  0.5646,Reconstruction Loss:  0.4865,KL Div:  312.5110
# Epoch: [24 / 100], Step: [580 / 4116],Loss:  0.4351,Reconstruction Loss:  0.3636,KL Div:  286.1034
# Epoch: [24 / 100], Step: [581 / 4116],Loss:  0.4890,Reconstruction Loss:  0.4119,KL Div:  308.3296
# Epoch: [24 / 100], Step: [582 / 4116],Loss:  0.5695,Reconstruction Loss:  0.4893,KL Div:  320.5905
# Epoch: [24 / 100], Step: [583 / 4116],Loss:  0.5667,Reconstruction Loss:  0.4824,KL Div:  337.1891
# Epoch: [24 / 100], Step: [584 / 4116],Loss:  0.5366,Reconstruction Loss:  0.4516,KL Div:  340.0307
# Epoch: [24 / 100], Step: [585 / 4116],Loss:  0.4347,Reconstruction Loss:  0.3561,KL Div:  314.2552
# Epoch: [24 / 100], Step: [586 / 4116],Loss:  0.5252,Reconstruction Loss:  0.4528,KL Div:  289.6514
# Epoch: [24 / 100], Step: [587 / 4116],Loss:  0.5505,Reconstruction Loss:  0.4704,KL Div:  320.4160
# Epoch: [24 / 100], Step: [588 / 4116],Loss:  0.4395,Reconstruction Loss:  0.3617,KL Div:  311.2371
# Epoch: [24 / 100], Step: [589 / 4116],Loss:  0.5064,Reconstruction Loss:  0.4349,KL Div:  286.0427
# Epoch: [24 / 100], Step: [590 / 4116],Loss:  0.4261,Reconstruction Loss:  0.3471,KL Div:  316.0503
# Epoch: [24 / 100], Step: [591 / 4116],Loss:  0.4723,Reconstruction Loss:  0.3822,KL Div:  360.1879
# Epoch: [24 / 100], Step: [592 / 4116],Loss:  0.4501,Reconstruction Loss:  0.3739,KL Div:  304.8877
# Epoch: [24 / 100], Step: [593 / 4116],Loss:  0.4715,Reconstruction Loss:  0.3904,KL Div:  324.4997
# Epoch: [24 / 100], Step: [594 / 4116],Loss:  0.5574,Reconstruction Loss:  0.4798,KL Div:  310.4638
# Epoch: [24 / 100], Step: [595 / 4116],Loss:  0.4988,Reconstruction Loss:  0.4186,KL Div:  320.6688
# Epoch: [24 / 100], Step: [596 / 4116],Loss:  0.5225,Reconstruction Loss:  0.4446,KL Div:  311.7852
# Epoch: [24 / 100], Step: [597 / 4116],Loss:  0.6279,Reconstruction Loss:  0.5517,KL Div:  304.5752
# Epoch: [24 / 100], Step: [598 / 4116],Loss:  0.4067,Reconstruction Loss:  0.3332,KL Div:  293.9624
# Epoch: [24 / 100], Step: [599 / 4116],Loss:  0.3731,Reconstruction Loss:  0.2880,KL Div:  340.3666
# Epoch: [24 / 100], Step: [600 / 4116],Loss:  0.5387,Reconstruction Loss:  0.4639,KL Div:  299.1443
# Epoch: [24 / 100], Step: [601 / 4116],Loss:  0.5019,Reconstruction Loss:  0.4300,KL Div:  287.7004
# Epoch: [24 / 100], Step: [752 / 4116],Loss:  0.4577,Reconstruction Loss:  0.3763,KL Div:  325.4954
# Epoch: [24 / 100], Step: [753 / 4116],Loss:  0.6650,Reconstruction Loss:  0.5916,KL Div:  293.3341
# Epoch: [24 / 100], Step: [754 / 4116],Loss:  0.3769,Reconstruction Loss:  0.2985,KL Div:  313.7218
# Epoch: [24 / 100], Step: [755 / 4116],Loss:  0.5154,Reconstruction Loss:  0.4373,KL Div:  312.5429
# Epoch: [24 / 100], Step: [756 / 4116],Loss:  0.6127,Reconstruction Loss:  0.5335,KL Div:  316.7162
# Epoch: [24 / 100], Step: [757 / 4116],Loss:  0.6202,Reconstruction Loss:  0.5423,KL Div:  311.5942
# Epoch: [24 / 100], Step: [758 / 4116],Loss:  0.4318,Reconstruction Loss:  0.3531,KL Div:  314.5265
# Epoch: [24 / 100], Step: [759 / 4116],Loss:  0.6264,Reconstruction Loss:  0.5391,KL Div:  349.0730
# Epoch: [24 / 100], Step: [760 / 4116],Loss:  0.4510,Reconstruction Loss:  0.3736,KL Div:  309.3534
# Epoch: [24 / 100], Step: [761 / 4116],Loss:  0.4195,Reconstruction Loss:  0.3444,KL Div:  300.1178
# Epoch: [24 / 100], Step: [762 / 4116],Loss:  0.5633,Reconstruction Loss:  0.4813,KL Div:  327.9908
# Epoch: [24 / 100], Step: [763 / 4116],Loss:  0.5936,Reconstruction Loss:  0.5131,KL Div:  322.0209
# Epoch: [24 / 100], Step: [764 / 4116],Loss:  0.6245,Reconstruction Loss:  0.5507,KL Div:  295.4322
# Epoch: [24 / 100], Step: [765 / 4116],Loss:  0.5567,Reconstruction Loss:  0.4777,KL Div:  315.9112
# Epoch: [24 / 100], Step: [766 / 4116],Loss:  0.6558,Reconstruction Loss:  0.5702,KL Div:  342.4247
# Epoch: [24 / 100], Step: [767 / 4116],Loss:  0.6716,Reconstruction Loss:  0.5982,KL Div:  293.8176
# Epoch: [24 / 100], Step: [768 / 4116],Loss:  0.4407,Reconstruction Loss:  0.3555,KL Div:  341.0704
# Epoch: [24 / 100], Step: [769 / 4116],Loss:  0.5341,Reconstruction Loss:  0.4613,KL Div:  291.0873
# Epoch: [24 / 100], Step: [770 / 4116],Loss:  0.5726,Reconstruction Loss:  0.4968,KL Div:  303.2885
# Epoch: [24 / 100], Step: [771 / 4116],Loss:  0.4688,Reconstruction Loss:  0.3924,KL Div:  305.4334
# Epoch: [24 / 100], Step: [772 / 4116],Loss:  0.5153,Reconstruction Loss:  0.4370,KL Div:  313.2839
# Epoch: [24 / 100], Step: [773 / 4116],Loss:  0.4543,Reconstruction Loss:  0.3886,KL Div:  262.7471
# Epoch: [24 / 100], Step: [774 / 4116],Loss:  0.3857,Reconstruction Loss:  0.3203,KL Div:  261.4182
# Epoch: [24 / 100], Step: [775 / 4116],Loss:  0.5743,Reconstruction Loss:  0.4927,KL Div:  326.3016
# Epoch: [24 / 100], Step: [776 / 4116],Loss:  0.4521,Reconstruction Loss:  0.3816,KL Div:  282.3130
# Epoch: [24 / 100], Step: [827 / 4116],Loss:  0.4653,Reconstruction Loss:  0.3864,KL Div:  315.5305
# Epoch: [24 / 100], Step: [828 / 4116],Loss:  0.5202,Reconstruction Loss:  0.4452,KL Div:  299.9966
# Epoch: [24 / 100], Step: [829 / 4116],Loss:  0.4912,Reconstruction Loss:  0.4135,KL Div:  310.7267
# Epoch: [24 / 100], Step: [830 / 4116],Loss:  0.4393,Reconstruction Loss:  0.3630,KL Div:  305.0734
# Epoch: [24 / 100], Step: [831 / 4116],Loss:  0.5388,Reconstruction Loss:  0.4528,KL Div:  344.0742
# Epoch: [24 / 100], Step: [832 / 4116],Loss:  0.4597,Reconstruction Loss:  0.3825,KL Div:  308.8305
# Epoch: [24 / 100], Step: [833 / 4116],Loss:  0.5288,Reconstruction Loss:  0.4576,KL Div:  284.6616
# Epoch: [24 / 100], Step: [834 / 4116],Loss:  0.6042,Reconstruction Loss:  0.5261,KL Div:  312.3795
# Epoch: [24 / 100], Step: [835 / 4116],Loss:  0.5203,Reconstruction Loss:  0.4544,KL Div:  263.5711
# Epoch: [24 / 100], Step: [836 / 4116],Loss:  0.6198,Reconstruction Loss:  0.5322,KL Div:  350.4344
# Epoch: [24 / 100], Step: [837 / 4116],Loss:  0.4635,Reconstruction Loss:  0.3930,KL Div:  282.1925
# Epoch: [24 / 100], Step: [838 / 4116],Loss:  0.4741,Reconstruction Loss:  0.3969,KL Div:  308.7177
# Epoch: [24 / 100], Step: [839 / 4116],Loss:  0.4361,Reconstruction Loss:  0.3571,KL Div:  315.9889
# Epoch: [24 / 100], Step: [840 / 4116],Loss:  0.4519,Reconstruction Loss:  0.3753,KL Div:  306.3667
# Epoch: [24 / 100], Step: [841 / 4116],Loss:  0.4534,Reconstruction Loss:  0.3793,KL Div:  296.2757
# Epoch: [24 / 100], Step: [842 / 4116],Loss:  0.5872,Reconstruction Loss:  0.5039,KL Div:  333.3128
# Epoch: [24 / 100], Step: [843 / 4116],Loss:  0.4186,Reconstruction Loss:  0.3461,KL Div:  290.3561
# Epoch: [24 / 100], Step: [844 / 4116],Loss:  0.6408,Reconstruction Loss:  0.5544,KL Div:  345.8013
# Epoch: [24 / 100], Step: [845 / 4116],Loss:  0.4981,Reconstruction Loss:  0.4191,KL Div:  315.9038
# Epoch: [24 / 100], Step: [846 / 4116],Loss:  0.5435,Reconstruction Loss:  0.4615,KL Div:  327.9055
# Epoch: [24 / 100], Step: [847 / 4116],Loss:  0.3984,Reconstruction Loss:  0.3209,KL Div:  310.0967
# Epoch: [24 / 100], Step: [848 / 4116],Loss:  0.5249,Reconstruction Loss:  0.4516,KL Div:  293.1346
# Epoch: [24 / 100], Step: [849 / 4116],Loss:  0.5306,Reconstruction Loss:  0.4528,KL Div:  311.1302
# Epoch: [24 / 100], Step: [850 / 4116],Loss:  0.4595,Reconstruction Loss:  0.3878,KL Div:  286.7586
# Epoch: [24 / 100], Step: [851 / 4116],Loss:  0.4070,Reconstruction Loss:  0.3322,KL Div:  298.9727
# Epoch: [24 / 100], Step: [877 / 4116],Loss:  0.7275,Reconstruction Loss:  0.6482,KL Div:  317.0338
# Epoch: [24 / 100], Step: [878 / 4116],Loss:  0.4893,Reconstruction Loss:  0.4133,KL Div:  303.8159
# Epoch: [24 / 100], Step: [879 / 4116],Loss:  0.4710,Reconstruction Loss:  0.4022,KL Div:  275.1650
# Epoch: [24 / 100], Step: [880 / 4116],Loss:  0.4061,Reconstruction Loss:  0.3309,KL Div:  300.6784
# Epoch: [24 / 100], Step: [881 / 4116],Loss:  0.4723,Reconstruction Loss:  0.3968,KL Div:  302.2793
# Epoch: [24 / 100], Step: [882 / 4116],Loss:  0.5423,Reconstruction Loss:  0.4644,KL Div:  311.3380
# Epoch: [24 / 100], Step: [883 / 4116],Loss:  0.4639,Reconstruction Loss:  0.3853,KL Div:  314.4432
# Epoch: [24 / 100], Step: [884 / 4116],Loss:  0.5451,Reconstruction Loss:  0.4661,KL Div:  315.7823
# Epoch: [24 / 100], Step: [885 / 4116],Loss:  0.5348,Reconstruction Loss:  0.4616,KL Div:  292.9893
# Epoch: [24 / 100], Step: [886 / 4116],Loss:  0.5137,Reconstruction Loss:  0.4372,KL Div:  305.9489
# Epoch: [24 / 100], Step: [887 / 4116],Loss:  0.4274,Reconstruction Loss:  0.3542,KL Div:  292.8933
# Epoch: [24 / 100], Step: [888 / 4116],Loss:  0.4383,Reconstruction Loss:  0.3519,KL Div:  345.7746
# Epoch: [24 / 100], Step: [889 / 4116],Loss:  0.4243,Reconstruction Loss:  0.3407,KL Div:  334.4167
# Epoch: [24 / 100], Step: [890 / 4116],Loss:  0.4999,Reconstruction Loss:  0.4204,KL Div:  318.2233
# Epoch: [24 / 100], Step: [891 / 4116],Loss:  0.4588,Reconstruction Loss:  0.3823,KL Div:  305.8730
# Epoch: [24 / 100], Step: [892 / 4116],Loss:  0.7319,Reconstruction Loss:  0.6593,KL Div:  290.4430
# Epoch: [24 / 100], Step: [893 / 4116],Loss:  0.5956,Reconstruction Loss:  0.5113,KL Div:  337.1213
# Epoch: [24 / 100], Step: [894 / 4116],Loss:  0.5294,Reconstruction Loss:  0.4502,KL Div:  316.8698
# Epoch: [24 / 100], Step: [895 / 4116],Loss:  0.4687,Reconstruction Loss:  0.3918,KL Div:  307.6010
# Epoch: [24 / 100], Step: [896 / 4116],Loss:  0.5758,Reconstruction Loss:  0.4995,KL Div:  305.1452
# Epoch: [24 / 100], Step: [897 / 4116],Loss:  0.5485,Reconstruction Loss:  0.4678,KL Div:  322.6332
# Epoch: [24 / 100], Step: [898 / 4116],Loss:  0.5054,Reconstruction Loss:  0.4278,KL Div:  310.6618
# Epoch: [24 / 100], Step: [899 / 4116],Loss:  0.4464,Reconstruction Loss:  0.3697,KL Div:  306.9060
# Epoch: [24 / 100], Step: [900 / 4116],Loss:  0.5451,Reconstruction Loss:  0.4654,KL Div:  318.8979
# Epoch: [24 / 100], Step: [901 / 4116],Loss:  0.4202,Reconstruction Loss:  0.3450,KL Div:  300.8642
# Epoch: [24 / 100], Step: [902 / 4116],Loss:  0.4066,Reconstruction Loss:  0.3345,KL Div:  288.2465
# Epoch: [24 / 100], Step: [903 / 4116],Loss:  0.4554,Reconstruction Loss:  0.3816,KL Div:  295.0123
# Epoch: [24 / 100], Step: [904 / 4116],Loss:  0.4894,Reconstruction Loss:  0.4144,KL Div:  299.9536
# Epoch: [24 / 100], Step: [905 / 4116],Loss:  0.4819,Reconstruction Loss:  0.4042,KL Div:  310.9887
# Epoch: [24 / 100], Step: [906 / 4116],Loss:  0.5323,Reconstruction Loss:  0.4556,KL Div:  306.4959
# Epoch: [24 / 100], Step: [907 / 4116],Loss:  0.6564,Reconstruction Loss:  0.5788,KL Div:  310.4556
# Epoch: [24 / 100], Step: [908 / 4116],Loss:  0.4600,Reconstruction Loss:  0.3731,KL Div:  347.7599
# Epoch: [24 / 100], Step: [909 / 4116],Loss:  0.5124,Reconstruction Loss:  0.4365,KL Div:  303.8218
# Epoch: [24 / 100], Step: [910 / 4116],Loss:  0.4720,Reconstruction Loss:  0.3917,KL Div:  321.2863
# Epoch: [24 / 100], Step: [911 / 4116],Loss:  0.4810,Reconstruction Loss:  0.4006,KL Div:  321.5865
# Epoch: [24 / 100], Step: [912 / 4116],Loss:  0.5573,Reconstruction Loss:  0.4796,KL Div:  310.8604
# Epoch: [24 / 100], Step: [913 / 4116],Loss:  0.4618,Reconstruction Loss:  0.3917,KL Div:  280.2104
# Epoch: [24 / 100], Step: [914 / 4116],Loss:  0.4953,Reconstruction Loss:  0.4164,KL Div:  315.4268
# Epoch: [24 / 100], Step: [915 / 4116],Loss:  0.4428,Reconstruction Loss:  0.3679,KL Div:  299.6010
# Epoch: [24 / 100], Step: [916 / 4116],Loss:  0.4051,Reconstruction Loss:  0.3251,KL Div:  320.2483
# Epoch: [24 / 100], Step: [917 / 4116],Loss:  0.6066,Reconstruction Loss:  0.5289,KL Div:  310.9630
# Epoch: [24 / 100], Step: [918 / 4116],Loss:  0.5360,Reconstruction Loss:  0.4539,KL Div:  328.2738
# Epoch: [24 / 100], Step: [919 / 4116],Loss:  0.6335,Reconstruction Loss:  0.5560,KL Div:  309.9580
# Epoch: [24 / 100], Step: [920 / 4116],Loss:  0.5164,Reconstruction Loss:  0.4384,KL Div:  311.9971
# Epoch: [24 / 100], Step: [921 / 4116],Loss:  0.5202,Reconstruction Loss:  0.4475,KL Div:  290.9235
# Epoch: [24 / 100], Step: [922 / 4116],Loss:  0.4353,Reconstruction Loss:  0.3582,KL Div:  308.6936
# Epoch: [24 / 100], Step: [923 / 4116],Loss:  0.6029,Reconstruction Loss:  0.5241,KL Div:  315.5762
# Epoch: [24 / 100], Step: [924 / 4116],Loss:  0.7215,Reconstruction Loss:  0.6421,KL Div:  317.6760
# Epoch: [24 / 100], Step: [925 / 4116],Loss:  0.5698,Reconstruction Loss:  0.4923,KL Div:  309.8441
# Epoch: [24 / 100], Step: [926 / 4116],Loss:  0.5680,Reconstruction Loss:  0.4912,KL Div:  307.1555
# Epoch: [24 / 100], Step: [927 / 4116],Loss:  0.4370,Reconstruction Loss:  0.3558,KL Div:  324.7554
# Epoch: [24 / 100], Step: [928 / 4116],Loss:  0.6366,Reconstruction Loss:  0.5515,KL Div:  340.1964
# Epoch: [24 / 100], Step: [929 / 4116],Loss:  0.4105,Reconstruction Loss:  0.3342,KL Div:  305.1954
# Epoch: [24 / 100], Step: [930 / 4116],Loss:  0.4563,Reconstruction Loss:  0.3752,KL Div:  324.1147
# Epoch: [24 / 100], Step: [931 / 4116],Loss:  0.6113,Reconstruction Loss:  0.5190,KL Div:  368.9781
# Epoch: [24 / 100], Step: [932 / 4116],Loss:  0.5202,Reconstruction Loss:  0.4523,KL Div:  271.4753
# Epoch: [24 / 100], Step: [933 / 4116],Loss:  0.5301,Reconstruction Loss:  0.4432,KL Div:  347.6472
# Epoch: [24 / 100], Step: [934 / 4116],Loss:  0.5806,Reconstruction Loss:  0.5015,KL Div:  316.2204
# Epoch: [24 / 100], Step: [935 / 4116],Loss:  0.4838,Reconstruction Loss:  0.4027,KL Div:  324.1283
# Epoch: [24 / 100], Step: [936 / 4116],Loss:  0.4376,Reconstruction Loss:  0.3745,KL Div:  252.4155
# Epoch: [24 / 100], Step: [937 / 4116],Loss:  0.3790,Reconstruction Loss:  0.3101,KL Div:  275.7223
# Epoch: [24 / 100], Step: [938 / 4116],Loss:  0.4833,Reconstruction Loss:  0.4036,KL Div:  318.5875
# Epoch: [24 / 100], Step: [939 / 4116],Loss:  0.5108,Reconstruction Loss:  0.4353,KL Div:  302.3128
# Epoch: [24 / 100], Step: [940 / 4116],Loss:  0.5435,Reconstruction Loss:  0.4693,KL Div:  297.0368
# Epoch: [24 / 100], Step: [941 / 4116],Loss:  0.6013,Reconstruction Loss:  0.5137,KL Div:  350.4071
# Epoch: [24 / 100], Step: [942 / 4116],Loss:  0.4891,Reconstruction Loss:  0.4143,KL Div:  299.1591
# Epoch: [24 / 100], Step: [943 / 4116],Loss:  0.5274,Reconstruction Loss:  0.4443,KL Div:  332.3559
# Epoch: [24 / 100], Step: [944 / 4116],Loss:  0.5122,Reconstruction Loss:  0.4372,KL Div:  299.8981
# Epoch: [24 / 100], Step: [945 / 4116],Loss:  0.4710,Reconstruction Loss:  0.3933,KL Div:  310.6928
# Epoch: [24 / 100], Step: [946 / 4116],Loss:  0.5927,Reconstruction Loss:  0.5119,KL Div:  323.0338
# Epoch: [24 / 100], Step: [947 / 4116],Loss:  0.5038,Reconstruction Loss:  0.4239,KL Div:  319.7404
# Epoch: [24 / 100], Step: [948 / 4116],Loss:  0.6380,Reconstruction Loss:  0.5558,KL Div:  329.0578
# Epoch: [24 / 100], Step: [949 / 4116],Loss:  0.3614,Reconstruction Loss:  0.2783,KL Div:  332.3643
# Epoch: [24 / 100], Step: [950 / 4116],Loss:  0.5105,Reconstruction Loss:  0.4325,KL Div:  311.8391
# Epoch: [24 / 100], Step: [951 / 4116],Loss:  0.5332,Reconstruction Loss:  0.4578,KL Div:  301.7595
# Epoch: [24 / 100], Step: [952 / 4116],Loss:  0.4739,Reconstruction Loss:  0.3993,KL Div:  298.5428
# Epoch: [24 / 100], Step: [953 / 4116],Loss:  0.4421,Reconstruction Loss:  0.3696,KL Div:  289.9844
# Epoch: [24 / 100], Step: [954 / 4116],Loss:  0.5078,Reconstruction Loss:  0.4412,KL Div:  266.7713
# Epoch: [24 / 100], Step: [955 / 4116],Loss:  0.5758,Reconstruction Loss:  0.5002,KL Div:  302.1616
# Epoch: [24 / 100], Step: [956 / 4116],Loss:  0.5313,Reconstruction Loss:  0.4535,KL Div:  311.0224
# Epoch: [24 / 100], Step: [957 / 4116],Loss:  0.5714,Reconstruction Loss:  0.4912,KL Div:  321.0054
# Epoch: [24 / 100], Step: [958 / 4116],Loss:  0.3833,Reconstruction Loss:  0.2970,KL Div:  345.4062
# Epoch: [24 / 100], Step: [959 / 4116],Loss:  0.5330,Reconstruction Loss:  0.4520,KL Div:  324.0746
# Epoch: [24 / 100], Step: [960 / 4116],Loss:  0.5308,Reconstruction Loss:  0.4513,KL Div:  317.6776
# Epoch: [24 / 100], Step: [961 / 4116],Loss:  0.6956,Reconstruction Loss:  0.6154,KL Div:  320.6788
# Epoch: [24 / 100], Step: [962 / 4116],Loss:  0.5448,Reconstruction Loss:  0.4666,KL Div:  312.9979
# Epoch: [24 / 100], Step: [963 / 4116],Loss:  0.5682,Reconstruction Loss:  0.4921,KL Div:  304.3854
# Epoch: [24 / 100], Step: [964 / 4116],Loss:  0.5044,Reconstruction Loss:  0.4261,KL Div:  313.4043
# Epoch: [24 / 100], Step: [965 / 4116],Loss:  0.5362,Reconstruction Loss:  0.4585,KL Div:  311.0932
# Epoch: [24 / 100], Step: [966 / 4116],Loss:  0.4592,Reconstruction Loss:  0.3765,KL Div:  330.9904
# Epoch: [24 / 100], Step: [967 / 4116],Loss:  0.4811,Reconstruction Loss:  0.4144,KL Div:  266.7107
# Epoch: [24 / 100], Step: [968 / 4116],Loss:  0.4349,Reconstruction Loss:  0.3636,KL Div:  285.1099
# Epoch: [24 / 100], Step: [969 / 4116],Loss:  0.4813,Reconstruction Loss:  0.3908,KL Div:  361.7107
# Epoch: [24 / 100], Step: [970 / 4116],Loss:  0.4951,Reconstruction Loss:  0.4290,KL Div:  264.6044
# Epoch: [24 / 100], Step: [971 / 4116],Loss:  0.4043,Reconstruction Loss:  0.3219,KL Div:  329.4410
# Epoch: [24 / 100], Step: [972 / 4116],Loss:  0.5871,Reconstruction Loss:  0.5161,KL Div:  284.3423
# Epoch: [24 / 100], Step: [973 / 4116],Loss:  0.4668,Reconstruction Loss:  0.3889,KL Div:  311.7052
# Epoch: [24 / 100], Step: [974 / 4116],Loss:  0.4207,Reconstruction Loss:  0.3476,KL Div:  292.5637
# Epoch: [24 / 100], Step: [975 / 4116],Loss:  0.4017,Reconstruction Loss:  0.3269,KL Div:  299.2678
# Epoch: [24 / 100], Step: [976 / 4116],Loss:  0.5396,Reconstruction Loss:  0.4601,KL Div:  317.9885
# Epoch: [24 / 100], Step: [977 / 4116],Loss:  0.4824,Reconstruction Loss:  0.4053,KL Div:  308.1356
# Epoch: [24 / 100], Step: [978 / 4116],Loss:  0.5292,Reconstruction Loss:  0.4453,KL Div:  335.4213
# Epoch: [24 / 100], Step: [979 / 4116],Loss:  0.5705,Reconstruction Loss:  0.4876,KL Div:  331.2855
# Epoch: [24 / 100], Step: [980 / 4116],Loss:  0.5143,Reconstruction Loss:  0.4360,KL Div:  313.3203
# Epoch: [24 / 100], Step: [981 / 4116],Loss:  0.5509,Reconstruction Loss:  0.4772,KL Div:  294.9438
# Epoch: [24 / 100], Step: [982 / 4116],Loss:  0.4463,Reconstruction Loss:  0.3683,KL Div:  311.7824
# Epoch: [24 / 100], Step: [983 / 4116],Loss:  0.5428,Reconstruction Loss:  0.4686,KL Div:  296.7852
# Epoch: [24 / 100], Step: [984 / 4116],Loss:  0.4007,Reconstruction Loss:  0.3254,KL Div:  301.0631
# Epoch: [24 / 100], Step: [985 / 4116],Loss:  0.6299,Reconstruction Loss:  0.5641,KL Div:  263.1269
# Epoch: [24 / 100], Step: [986 / 4116],Loss:  0.5910,Reconstruction Loss:  0.5135,KL Div:  309.7882
# Epoch: [24 / 100], Step: [987 / 4116],Loss:  0.5127,Reconstruction Loss:  0.4366,KL Div:  304.7059
# Epoch: [24 / 100], Step: [988 / 4116],Loss:  0.4550,Reconstruction Loss:  0.3775,KL Div:  309.9589
# Epoch: [24 / 100], Step: [989 / 4116],Loss:  0.5286,Reconstruction Loss:  0.4478,KL Div:  322.8375
# Epoch: [24 / 100], Step: [990 / 4116],Loss:  0.5210,Reconstruction Loss:  0.4411,KL Div:  319.3616
# Epoch: [24 / 100], Step: [991 / 4116],Loss:  0.4576,Reconstruction Loss:  0.3794,KL Div:  312.4223
# Epoch: [24 / 100], Step: [992 / 4116],Loss:  0.3621,Reconstruction Loss:  0.2807,KL Div:  325.3748
# Epoch: [24 / 100], Step: [993 / 4116],Loss:  0.5270,Reconstruction Loss:  0.4530,KL Div:  295.9635
# Epoch: [24 / 100], Step: [994 / 4116],Loss:  0.4481,Reconstruction Loss:  0.3710,KL Div:  308.0341
# Epoch: [24 / 100], Step: [995 / 4116],Loss:  0.6225,Reconstruction Loss:  0.5455,KL Div:  307.6357
# Epoch: [24 / 100], Step: [996 / 4116],Loss:  0.6006,Reconstruction Loss:  0.5131,KL Div:  349.8839
# Epoch: [24 / 100], Step: [997 / 4116],Loss:  0.5012,Reconstruction Loss:  0.4237,KL Div:  309.6640
# Epoch: [24 / 100], Step: [998 / 4116],Loss:  0.4684,Reconstruction Loss:  0.3951,KL Div:  293.2561
# Epoch: [24 / 100], Step: [999 / 4116],Loss:  0.5587,Reconstruction Loss:  0.4755,KL Div:  332.7393
# Epoch: [24 / 100], Step: [1000 / 4116],Loss:  0.5642,Reconstruction Loss:  0.4847,KL Div:  318.2034
# Epoch: [24 / 100], Step: [1001 / 4116],Loss:  0.4889,Reconstruction Loss:  0.4101,KL Div:  315.0825
# Epoch: [24 / 100], Step: [1002 / 4116],Loss:  0.4754,Reconstruction Loss:  0.3927,KL Div:  330.7549
# Epoch: [24 / 100], Step: [1003 / 4116],Loss:  0.5082,Reconstruction Loss:  0.4292,KL Div:  315.7349
# Epoch: [24 / 100], Step: [1004 / 4116],Loss:  0.5001,Reconstruction Loss:  0.4254,KL Div:  298.7911
# Epoch: [24 / 100], Step: [1005 / 4116],Loss:  0.5757,Reconstruction Loss:  0.5002,KL Div:  302.0621
# Epoch: [24 / 100], Step: [1006 / 4116],Loss:  0.4495,Reconstruction Loss:  0.3641,KL Div:  341.6420
# Epoch: [24 / 100], Step: [1007 / 4116],Loss:  0.4218,Reconstruction Loss:  0.3527,KL Div:  276.3745
# Epoch: [24 / 100], Step: [1008 / 4116],Loss:  0.6601,Reconstruction Loss:  0.5803,KL Div:  319.3950
# Epoch: [24 / 100], Step: [1009 / 4116],Loss:  0.5029,Reconstruction Loss:  0.4265,KL Div:  305.3418
# Epoch: [24 / 100], Step: [1010 / 4116],Loss:  0.4885,Reconstruction Loss:  0.4106,KL Div:  311.5405
# Epoch: [24 / 100], Step: [1011 / 4116],Loss:  0.5094,Reconstruction Loss:  0.4319,KL Div:  309.9203
# Epoch: [24 / 100], Step: [1012 / 4116],Loss:  0.5897,Reconstruction Loss:  0.5099,KL Div:  319.0865
# Epoch: [24 / 100], Step: [1013 / 4116],Loss:  0.4445,Reconstruction Loss:  0.3627,KL Div:  327.2762
# Epoch: [24 / 100], Step: [1014 / 4116],Loss:  0.5630,Reconstruction Loss:  0.4887,KL Div:  297.0924
# Epoch: [24 / 100], Step: [1015 / 4116],Loss:  0.5183,Reconstruction Loss:  0.4348,KL Div:  333.7064
# Epoch: [24 / 100], Step: [1016 / 4116],Loss:  0.6389,Reconstruction Loss:  0.5657,KL Div:  292.9608
# Epoch: [24 / 100], Step: [1017 / 4116],Loss:  0.5056,Reconstruction Loss:  0.4353,KL Div:  281.5294
# Epoch: [24 / 100], Step: [1018 / 4116],Loss:  0.5494,Reconstruction Loss:  0.4743,KL Div:  300.5584
# Epoch: [24 / 100], Step: [1019 / 4116],Loss:  0.4284,Reconstruction Loss:  0.3473,KL Div:  324.2379
# Epoch: [24 / 100], Step: [1020 / 4116],Loss:  0.3711,Reconstruction Loss:  0.3006,KL Div:  281.9127
# Epoch: [24 / 100], Step: [1021 / 4116],Loss:  0.5678,Reconstruction Loss:  0.4867,KL Div:  324.3773
# Epoch: [24 / 100], Step: [1022 / 4116],Loss:  0.5082,Reconstruction Loss:  0.4360,KL Div:  288.6290
# Epoch: [24 / 100], Step: [1023 / 4116],Loss:  0.5676,Reconstruction Loss:  0.4934,KL Div:  296.9885
# Epoch: [24 / 100], Step: [1024 / 4116],Loss:  0.4102,Reconstruction Loss:  0.3384,KL Div:  287.1114
# Epoch: [24 / 100], Step: [1025 / 4116],Loss:  0.4848,Reconstruction Loss:  0.4096,KL Div:  301.0487
# Epoch: [24 / 100], Step: [1051 / 4116],Loss:  0.6949,Reconstruction Loss:  0.6175,KL Div:  309.4677
# Epoch: [24 / 100], Step: [1052 / 4116],Loss:  0.6612,Reconstruction Loss:  0.5829,KL Div:  313.1910
# Epoch: [24 / 100], Step: [1053 / 4116],Loss:  0.5194,Reconstruction Loss:  0.4474,KL Div:  288.1429
# Epoch: [24 / 100], Step: [1054 / 4116],Loss:  0.4328,Reconstruction Loss:  0.3561,KL Div:  306.5707
# Epoch: [24 / 100], Step: [1055 / 4116],Loss:  0.4710,Reconstruction Loss:  0.3916,KL Div:  317.8265
# Epoch: [24 / 100], Step: [1056 / 4116],Loss:  0.5003,Reconstruction Loss:  0.4284,KL Div:  287.6610
# Epoch: [24 / 100], Step: [1057 / 4116],Loss:  0.6960,Reconstruction Loss:  0.6167,KL Div:  317.2365
# Epoch: [24 / 100], Step: [1058 / 4116],Loss:  0.5493,Reconstruction Loss:  0.4774,KL Div:  287.5150
# Epoch: [24 / 100], Step: [1059 / 4116],Loss:  0.5458,Reconstruction Loss:  0.4676,KL Div:  312.6317
# Epoch: [24 / 100], Step: [1060 / 4116],Loss:  0.5069,Reconstruction Loss:  0.4276,KL Div:  317.0504
# Epoch: [24 / 100], Step: [1061 / 4116],Loss:  0.6278,Reconstruction Loss:  0.5499,KL Div:  311.5743
# ...
# Epoch: [25 / 100], Step: [1303 / 4116],Loss:  0.4601,Reconstruction Loss:  0.3828,KL Div:  309.1683
# Epoch: [25 / 100], Step: [1304 / 4116],Loss:  0.4566,Reconstruction Loss:  0.3828,KL Div:  295.1097
# Epoch: [25 / 100], Step: [1305 / 4116],Loss:  0.3657,Reconstruction Loss:  0.2870,KL Div:  314.8521
# Epoch: [25 / 100], Step: [1306 / 4116],Loss:  0.4635,Reconstruction Loss:  0.3889,KL Div:  298.4518
# Epoch: [25 / 100], Step: [1307 / 4116],Loss:  0.5006,Reconstruction Loss:  0.4193,KL Div:  325.3969
# Epoch: [25 / 100], Step: [1308 / 4116],Loss:  0.4849,Reconstruction Loss:  0.3939,KL Div:  363.8416
# Epoch: [25 / 100], Step: [1309 / 4116],Loss:  0.4313,Reconstruction Loss:  0.3579,KL Div:  293.8977
# Epoch: [25 / 100], Step: [1310 / 4116],Loss:  0.5143,Reconstruction Loss:  0.4383,KL Div:  303.8583
# Epoch: [25 / 100], Step: [1311 / 4116],Loss:  0.4249,Reconstruction Loss:  0.3499,KL Div:  299.7417
# Epoch: [25 / 100], Step: [1312 / 4116],Loss:  0.5124,Reconstruction Loss:  0.4371,KL Div:  301.4507
# Epoch: [25 / 100], Step: [1313 / 4116],Loss:  0.4775,Reconstruction Loss:  0.3984,KL Div:  316.4270
# Epoch: [25 / 100], Step: [1314 / 4116],Loss:  0.4154,Reconstruction Loss:  0.3400,KL Div:  301.5601
# Epoch: [25 / 100], Step: [1315 / 4116],Loss:  0.4482,Reconstruction Loss:  0.3628,KL Div:  341.4570
# Epoch: [25 / 100], Step: [1316 / 4116],Loss:  0.5881,Reconstruction Loss:  0.5186,KL Div:  278.2155
# Epoch: [25 / 100], Step: [1317 / 4116],Loss:  0.5767,Reconstruction Loss:  0.4944,KL Div:  329.0101
# Epoch: [25 / 100], Step: [1318 / 4116],Loss:  0.5497,Reconstruction Loss:  0.4723,KL Div:  309.5894
# Epoch: [25 / 100], Step: [1319 / 4116],Loss:  0.4778,Reconstruction Loss:  0.3999,KL Div:  311.3834
# Epoch: [25 / 100], Step: [1320 / 4116],Loss:  0.5269,Reconstruction Loss:  0.4457,KL Div:  324.9273
# Epoch: [25 / 100], Step: [1321 / 4116],Loss:  0.5229,Reconstruction Loss:  0.4539,KL Div:  275.9631
# Epoch: [25 / 100], Step: [1322 / 4116],Loss:  0.4756,Reconstruction Loss:  0.3903,KL Div:  341.4559
# Epoch: [25 / 100], Step: [1323 / 4116],Loss:  0.4691,Reconstruction Loss:  0.3856,KL Div:  334.1841
# Epoch: [25 / 100], Step: [1324 / 4116],Loss:  0.6334,Reconstruction Loss:  0.5485,KL Div:  339.4214
# Epoch: [25 / 100], Step: [1325 / 4116],Loss:  0.3615,Reconstruction Loss:  0.2732,KL Div:  353.3312
# Epoch: [25 / 100], Step: [1326 / 4116],Loss:  0.5448,Reconstruction Loss:  0.4746,KL Div:  280.7945
# Epoch: [25 / 100], Step: [1327 / 4116],Loss:  0.4716,Reconstruction Loss:  0.3964,KL Div:  300.5649
# Epoch: [25 / 100], Step: [1328 / 4116],Loss:  0.5610,Reconstruction Loss:  0.4925,KL Div:  273.8381
# Epoch: [25 / 100], Step: [1329 / 4116],Loss:  0.4241,Reconstruction Loss:  0.3472,KL Div:  307.5805
# Epoch: [25 / 100], Step: [1330 / 4116],Loss:  0.5166,Reconstruction Loss:  0.4378,KL Div:  314.8562
# Epoch: [25 / 100], Step: [1331 / 4116],Loss:  0.4956,Reconstruction Loss:  0.4224,KL Div:  292.6114
# Epoch: [25 / 100], Step: [1332 / 4116],Loss:  0.4962,Reconstruction Loss:  0.4256,KL Div:  282.5406
# Epoch: [25 / 100], Step: [1333 / 4116],Loss:  0.5667,Reconstruction Loss:  0.4918,KL Div:  299.8129
# Epoch: [25 / 100], Step: [1334 / 4116],Loss:  0.4704,Reconstruction Loss:  0.3928,KL Div:  310.2365
# Epoch: [25 / 100], Step: [1335 / 4116],Loss:  0.5647,Reconstruction Loss:  0.4896,KL Div:  300.3657
# Epoch: [25 / 100], Step: [1336 / 4116],Loss:  0.5529,Reconstruction Loss:  0.4735,KL Div:  317.4402
# Epoch: [25 / 100], Step: [1337 / 4116],Loss:  0.5735,Reconstruction Loss:  0.4965,KL Div:  307.9048
# Epoch: [25 / 100], Step: [1338 / 4116],Loss:  0.5570,Reconstruction Loss:  0.4837,KL Div:  293.2399
# Epoch: [25 / 100], Step: [1339 / 4116],Loss:  0.5307,Reconstruction Loss:  0.4603,KL Div:  281.9675
# Epoch: [25 / 100], Step: [1340 / 4116],Loss:  0.4924,Reconstruction Loss:  0.4163,KL Div:  304.3469
# Epoch: [25 / 100], Step: [1440 / 4116],Loss:  0.4099,Reconstruction Loss:  0.3298,KL Div:  320.3571
# Epoch: [25 / 100], Step: [1441 / 4116],Loss:  0.4818,Reconstruction Loss:  0.4084,KL Div:  293.4780
# Epoch: [25 / 100], Step: [1442 / 4116],Loss:  0.4992,Reconstruction Loss:  0.4216,KL Div:  310.2854
# Epoch: [25 / 100], Step: [1443 / 4116],Loss:  0.5233,Reconstruction Loss:  0.4474,KL Div:  303.6620
# Epoch: [25 / 100], Step: [1444 / 4116],Loss:  0.3884,Reconstruction Loss:  0.3171,KL Div:  284.9039
# Epoch: [25 / 100], Step: [1445 / 4116],Loss:  0.5490,Reconstruction Loss:  0.4762,KL Div:  291.1992
# Epoch: [25 / 100], Step: [1446 / 4116],Loss:  0.4687,Reconstruction Loss:  0.3904,KL Div:  313.5822
# Epoch: [25 / 100], Step: [1447 / 4116],Loss:  0.4236,Reconstruction Loss:  0.3463,KL Div:  309.2592
# Epoch: [25 / 100], Step: [1448 / 4116],Loss:  0.4937,Reconstruction Loss:  0.4123,KL Div:  325.2390
# Epoch: [25 / 100], Step: [1449 / 4116],Loss:  0.3836,Reconstruction Loss:  0.3092,KL Div:  297.5391
# Epoch: [25 / 100], Step: [1450 / 4116],Loss:  0.3467,Reconstruction Loss:  0.2667,KL Div:  320.1073
# Epoch: [25 / 100], Step: [1451 / 4116],Loss:  0.5383,Reconstruction Loss:  0.4568,KL Div:  326.1168
# Epoch: [25 / 100], Step: [1452 / 4116],Loss:  0.5044,Reconstruction Loss:  0.4247,KL Div:  318.6411
# Epoch: [25 / 100], Step: [1453 / 4116],Loss:  0.4666,Reconstruction Loss:  0.3842,KL Div:  329.6219
# Epoch: [25 / 100], Step: [1454 / 4116],Loss:  0.4718,Reconstruction Loss:  0.3946,KL Div:  308.7918
# Epoch: [25 / 100], Step: [1455 / 4116],Loss:  0.5221,Reconstruction Loss:  0.4406,KL Div:  325.9952
# Epoch: [25 / 100], Step: [1456 / 4116],Loss:  0.4331,Reconstruction Loss:  0.3523,KL Div:  323.1581
# Epoch: [25 / 100], Step: [1457 / 4116],Loss:  0.4913,Reconstruction Loss:  0.4118,KL Div:  317.9781
# Epoch: [25 / 100], Step: [1458 / 4116],Loss:  0.5796,Reconstruction Loss:  0.5036,KL Div:  303.9522
# Epoch: [25 / 100], Step: [1459 / 4116],Loss:  0.5950,Reconstruction Loss:  0.5227,KL Div:  289.4024
# Epoch: [25 / 100], Step: [1460 / 4116],Loss:  0.4214,Reconstruction Loss:  0.3403,KL Div:  324.5029
# Epoch: [25 / 100], Step: [1461 / 4116],Loss:  0.4711,Reconstruction Loss:  0.3957,KL Div:  301.4291
# Epoch: [25 / 100], Step: [1462 / 4116],Loss:  0.5130,Reconstruction Loss:  0.4315,KL Div:  325.8806

# %% [markdown]
# # Plot the Loss Curve

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 5))
plt.plot(train_losses, label='Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('VAE Loss over Time')
plt.legend()
plt.show()
